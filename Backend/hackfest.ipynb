# %% [markdown]
# HACKFEST 2024

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv("dataset_hackfest.csv")
df.shape
# Out:
# (149, 6)

# %%
df.head(25)
# Out:
#    LOCATION  HOTEL PRICE  SELF ALLOWANCE  FOOD AND DINING  TRAVEL COST  \
# 0    KERALA         6500           17000             1300         6500
# 1    KERALA         3200           17000             1000         6500
# 2    KERALA        13500           17000             2500         6500
# 3    KERALA        22100           17000             2700         6500
# 4    KERALA         9500           17000             2300         6500
# 5    KERALA         3900           17000             1400         6500
# 6    KERALA         4200           17000             1400         6500
# 7    KERALA        14000           17000             2300         6500
# 8    KERALA         7000           17000             1850         6500
# 9    KERALA         5000           17000             1300         6500
# 10   KERALA         3000           17000             1000         6500
# 11   KERALA         6500           17000             1300         6500
# ...

# %%
df.size
# Out:
# 894

# %%
features = ['HOTEL PRICE', 'SELF ALLOWANCE', 'FOOD AND DINING', 'TRAVEL COST']
X1 = df[features]  
y1 = df['TRAVEL COST']
model = LinearRegression()
model.fit(X1, y1)
# Out:
# LinearRegression()

# %%
print("Coefficients:")
for feature, coef in zip(features, model.coef_):
    print(f"- {feature}: {coef:.3f}")

print("\nIntercept:", end=" ")
print(f"{model.intercept_:.3f}")
# Out:
# Coefficients:
# - HOTEL PRICE: -0.000
# - SELF ALLOWANCE: 0.000
# - FOOD AND DINING: 0.000
# - TRAVEL COST: 1.000
#
# Intercept: -0.000

# %%
X2 = df[features]
y2 = df['HOTEL PRICE']
model = LinearRegression()
model.fit(X2, y2)
# Out:
# LinearRegression()

# %%
print("Coefficients:")
for feature, coef in zip(features, model.coef_):
    print(f"- {feature}: {coef:.3f}")

print("\nIntercept:", end=" ")
print(f"{model.intercept_:.3f}")
# Out:
# Coefficients:
# - HOTEL PRICE: 1.000
# - SELF ALLOWANCE: -0.000
# - FOOD AND DINING: 0.000
# - TRAVEL COST: -0.000
#
# Intercept: 0.000

# %%
X3 = df[features]
y3 = df['FOOD AND DINING']
model = LinearRegression()
model.fit(X3, y3)
# Out:
# LinearRegression()

# %%
print("Coefficients:")
for feature, coef in zip(features, model.coef_):
    print(f"- {feature}: {coef:.3f}")

print("\nIntercept:", end=" ")
print(f"{model.intercept_:.3f}")
# Out:
# Coefficients:
# - HOTEL PRICE: -0.000
# - SELF ALLOWANCE: 0.000
# - FOOD AND DINING: 1.000
# - TRAVEL COST: -0.000
#
# Intercept: -0.000

# %%
X4 = df[features]
y4 = df['SELF ALLOWANCE']
model = LinearRegression()
model.fit(X4, y4)
# Out:
# LinearRegression()

# %%
print("Coefficients:")
for feature, coef in zip(features, model.coef_):
    print(f"- {feature}: {coef:.3f}")

print("\nIntercept:", end=" ")
print(f"{model.intercept_:.3f}")
# Out:
# Coefficients:
# - HOTEL PRICE: -0.000
# - SELF ALLOWANCE: 1.000
# - FOOD AND DINING: 0.000
# - TRAVEL COST: 0.000
#
# Intercept: -0.000

# %%
from sklearn.metrics import r2_score

# Predict travel costs on the data 
y_preds_1 = model.predict(X1)

# Calculate R-squared score
r1 = r2_score(y1, y_preds_1)

print("Linear Regression Model Accuracy for Travel Cost:")
print(f"R-squared (R2): {r1:.1f}")
# Out:
# Linear Regression Model Accuracy for Travel Cost:
# R-squared (R2): -95.6

# %%
y_preds_2 = model.predict(X2)

# Calculate R-squared score
r2 = r2_score(y2, y_preds_2)

print("Linear Regression Model Accuracy for Hotel Cost:")
print(f"R-squared (R2): {r2:.1f}")
# Out:
# Linear Regression Model Accuracy for Hotel Cost:
# R-squared (R2): -5.4

# %%
y_preds_3 = model.predict(X3)

# Calculate R-squared score
r3 = r2_score(y3, y_preds_3)

print("Linear Regression Model Accuracy for Food and Dining:")
print(f"R-squared (R2): {r3:.1f}")
# Out:
# Linear Regression Model Accuracy for Food and Dining:
# R-squared (R2): -885.2

# %%
y_preds = model.predict(X4)

# Calculate R-squared score
r4 = r2_score(y4, y_preds)

print("Linear Regression Model Accuracy Self Allowance:")
print(f"R-squared (R2): {r4:.1f}")
# Out:
# Linear Regression Model Accuracy Self Allowance:
# R-squared (R2): 1.0

# %%
X5 = df[features]
y5 = df['TOTAL COST']
model = LinearRegression()
model.fit(X5, y5)
# Out:
# LinearRegression()

# %%
# Predict travel costs on the data 
y_preds_4 = model.predict(X5)

# Calculate R-squared score
r5 = r2_score(y5, y_preds_4)

print("Linear Regression Model Accuracy for Travel Cost:")
print(f"R-squared (R2): {r5:.1f}")
# Out:
# Linear Regression Model Accuracy for Travel Cost:
# R-squared (R2): 1.0

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

model = LinearRegression()

X_train, X_test, y_train, y_test = train_test_split(X5, y_preds_4, test_size=0.4, random_state=42)

model.fit(X_train, y_train)

predictions_train = model.predict(X_train)
predictions_test = model.predict(X_test)

train_mse = mean_squared_error(y_train, predictions_train)
test_mse = mean_squared_error(y_test, predictions_test)

print("The mean squared error on the training set is: ", train_mse)
print("The mean squared error on the testing set is:", test_mse)
print("Model score is : ", model.score(X_train, y_train))
# Out:
# The mean squared error on the training set is:  2.8239388462709204e-22
# The mean squared error on the testing set is: 2.642566330236072e-22
# Model score is :  1.0
